# %%
import random
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM,Activation
from tensorflow.keras.optimizers import RMSprop

# %%
filepath = tf.keras.utils.get_file('shakespeare.txt',
        'https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt')

# %%
text = open(filepath, 'rb').read().decode(encoding='utf-8').lower()

# %%
text = text[300000:800000]

# %%
characters = sorted(set(text))

char_to_index = dict((c, i) for i, c in enumerate(characters))
index_to_char = dict((i, c) for i, c in enumerate(characters))

# %%
SEQ_LENGTH = 40
STEP_SIZE = 3

sentences = []
next_char = []

# %%
for i in range(0, len(text) - SEQ_LENGTH, STEP_SIZE):
    sentences.append(text[i: i + SEQ_LENGTH])
    next_char.append(text[i + SEQ_LENGTH])

# %%
x = np.zeros((len(sentences), SEQ_LENGTH,
              len(characters)), dtype=np.bool)
y = np.zeros((len(sentences),
              len(characters)), dtype=np.bool)

for i, satz in enumerate(sentences):
    for t, char in enumerate(satz):
        x[i, t, char_to_index[char]] = 1
    y[i, char_to_index[next_char[i]]] = 1

# %%
import random
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.layers import Activation, Dense, LSTM

# %%
model = Sequential()
model.add(LSTM(128,
               input_shape=(SEQ_LENGTH,
                            len(characters))))
model.add(Dense(len(characters)))
model.add(Activation('softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(learning_rate=0.01)) # Change 'lr' to 'learning_rate'

model.fit(x, y, batch_size=256, epochs=4)
# Out:
# Epoch 1/4
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 124s 188ms/step - loss: 2.4697
# Epoch 2/4
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 126s 194ms/step - loss: 1.7730
# Epoch 3/4
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 142s 195ms/step - loss: 1.6127
# Epoch 4/4
# 651/651 ━━━━━━━━━━━━━━━━━━━━ 127s 195ms/step - loss: 1.5250

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def generate_text(length, temperature):
    start_index = random.randint(0, len(text) - SEQ_LENGTH - 1)
    generated = ''
    sentence = text[start_index: start_index + SEQ_LENGTH]
    generated += sentence
    for i in range(length):
        x_predictions = np.zeros((1, SEQ_LENGTH, len(characters)))
        for t, char in enumerate(sentence):
            x_predictions[0, t, char_to_index[char]] = 1

        predictions = model.predict(x_predictions, verbose=0)[0]
        next_index = sample(predictions,
                                 temperature)
        next_character = index_to_char[next_index]

        generated += next_character
        sentence = sentence[1:] + next_character
    return generated

# %%
print(generate_text(300, 0.2))
# Out:
# swept suspicion from our seat
# and made of the sence the world the rest
# to shall not should be the world the words,
# the both the world the courty the server
# to the great the true the country great the tears,
# the strife and the stare of the court, the see
# the world the true the fortune of the court,
# and there i will be the heart and the wor

# %%
print(generate_text(300, 0.4))
# Out:
# !
#
# gloucester:
# what, will the aspiring be the great thee to me.
#
# romeo:
# now i would as the wastand and the fortue shone
# the fortune and strang the world the great be not soul see,
# shall be speek the set the england thee,
# and the bear the pricest the seepice and thee with with him:
# shall be see the world, the prince the cousin of thee,
# wit

# %%
print(generate_text(300,0.6))
# Out:
# ds,
# this blessed plot, this earth, this love away be death,
# and shall be rest cousin of should me the fair of thee,
# with a care, strengthy tousand with the counts to me,
# and england with the corsent in eye your fury and ne'er's words,
# but the great stand the great on theear'd belians
# which there heart the carged them, not they shall speek

# %%
print(generate_text(300,0.8))
# Out:
# should she do here?
# my dismal scene i never pause that the of,
# as in the cousined beful with thee were the heart.
# o, with he was we gurst and bred consent.
#
# queen margaret:
# stift his straight ade restering, ow stall
# that when, which i hath she will in she chearl
# in agares, it are and parence when justich:
# are all not proseet his shame wit

# %%
print(generate_text(300,1.0))
# Out:
# ith rosaline, my ghostly father? no;
# i have to will as patednl i abroperts,
# it ons of a cup, what i'll foilly an ed.
#
# first lust withought:
# show the oferge the in die cold to dake
# to daurt of yet a tarmers edward: the crown:
# for the for the ceepts to plarenterns yet in hearth
# of tallandbany til of to so not at, as i'll death:
# your sumfet
